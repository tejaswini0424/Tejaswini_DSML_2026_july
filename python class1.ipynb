# %%
text = "Edukron data science and data engineering batch 2026"
#indexing expression to print "Edukron"
print(text[0:7])
print(text[-52:-45])
# Out:
# Edukron
# Edukron

# %%
text = "Edukron data science and data engineering batch 2026"
#indexing expression to print "data"
print(text[8:12])
print(text[-44:-40])
# Out:
# data
# data

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print"science"
print(text[13:20])
print(text[-39:-31])
# Out:
# science
# science

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "and"
print(text[21:24])
print(text[-31:-27])
# Out:
# and
# and

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "data engineering"
print(text[24:41])
print(text[-27:-10])
# Out:
#  data engineering
# data engineering

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "engineering"
print(text[30:41])
print(text[-22:-11])
# Out:
# engineering
# engineering

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "batch"
print(text[42:47])
print(text[-10:-5])
# Out:
# batch
# batch

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "2026"
print(text[48:52])
print(text[-5:])
# Out:
# 2026
#  2026

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "science and data"
print(text[13:29])
print(text[-39:-23])
# Out:
# science and data
# science and data

# %%
text="Edukron data science and data engineering batch 2026"
#indexing expression to print "data science and data engineering"

print(text[8:41])
print(text[-44:-11])
# Out:
# data science and data engineering
# data science and data engineering
