# %%
#python program to calculate the square root of a number using math module
import math
number = int(input("Enter a number: "))
sqrt = math.sqrt(number)
print("The square root of", number, "is", sqrt)
# Out:
# Enter a number: 25
# The square root of 25 is 5.0

# %%
#find the cube root of a given number using matematical operations
import math
number = int(input("Enter a number: "))
cube_root = math.pow(number, 1/3)
print("The cube root of", number, "is", cube_root)
# Out:
# Enter a number: 27
# The cube root of 27 is 3.0

# %%
#calculate the factorial of a number using math.factorial
import math
number = int(input("Enter a number: "))
factorial = math.factorial(number)
print("The factorial of", number, "is", factorial)
# Out:
# Enter a number: 55
# The factorial of 55 is 12696403353658275925965100847566516959580321051449436762275840000000000000

# %%
#find the greatest common divisor of two numbers using math.gcd
import math
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
gcd = math.gcd(number1, number2)
print("The greatest common divisor of", number1, "and", number2, "is", gcd)
# Out:
# Enter the first number: 24
# Enter the second number: 36
# The greatest common divisor of 24 and 36 is 12

# %%
#find the lcm of two numbers using math.lcm
import math
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
lcm = math.lcm(number1, number2)
print("The least common multiple of", number1, "and", number2, "is", lcm)
# Out:
# Enter the first number: 24
# Enter the second number: 36
# The least common multiple of 24 and 36 is 72

# %%
#calculate the value of 5 raised to the power of 8 using math.pow
import math
result = math.pow(5, 8)
print("The value of 5 raised to the power of 8 is", result)
# Out:
# The value of 5 raised to the power of 8 is 390625.0

# %%
#find the absolute value of anegative decimal number using math.fabs
import math
number = -3.14
absolute_value = math.fabs(number)
print("The absolute value of", number, "is", absolute_value)
# Out:
# The absolute value of -3.14 is 3.14

# %%
#round a floating point number up using math.ceil
import math
number = 3.14
rounded_up = math.ceil(number)
print("The rounded up value of", number, "is", rounded_up)
# Out:
# The rounded up value of 3.14 is 4

# %%
#round a floating point number using math.floor
import math
number = 3.14
rounded_down = math.floor(number)
print("The rounded down value of", number, "is", rounded_down)
# Out:
# The rounded down value of 3.14 is 3

# %%
#find the remainder of two numbers using math.fmod
import math
number1 = 10
number2 = 3
remainder = math.fmod(number1, number2)
print("The remainder of", number1, "divided by", number2, "is", remainder)
# Out:
# The remainder of 10 divided by 3 is 1.0

# %%
#find the quotient and remainder using divmod
import math
number1 = 10
number2 = 3
quotient, remainder = divmod(number1, number2)
print("The quotient of", number1, "divided by", number2, "is", quotient)
print("The remainder of", number1, "divided by", number2, "is", remainder)
# Out:
# The quotient of 10 divided by 3 is 3
# The remainder of 10 divided by 3 is 1

# %%
#calculate the sine,cosine,and tangent of 45 degrees
import math
angle = math.radians(45)
sine = math.sin(angle)
cosine = math.cos(angle)
tangent = math.tan(angle)
print("The sine of 45 degrees is", sine)
print("The cosine of 45 degrees is", cosine)
print("The tangent of 45 degrees is", tangent)
# Out:
# The sine of 45 degrees is 0.7071067811865475
# The cosine of 45 degrees is 0.7071067811865476
# The tangent of 45 degrees is 0.9999999999999999

# %%
#convert an angle from degrees to radians
import math
angle_degrees = 45
angle_radians = math.radians(angle_degrees)
print("The angle in radians is", angle_radians)
# Out:
# The angle in radians is 0.7853981633974483

# %%
#convert an angle from radians to degrees
import math
angle_radians = 0.7853981633974483
angle_degrees = math.degrees(angle_radians)
print("The angle in degrees is", angle_degrees)
# Out:
# The angle in degrees is 45.0

# %%
#find the logarithm (base10)of anumber using math.log10
import math
number = 100
logarithm = math.log10(number)
print("The logarithm of", number, "is", logarithm)
# Out:
# The logarithm of 100 is 2.0

# %%
#find the natural logarithm of a number using math.log
import math
number = 2.718281828459045
natural_logarithm = math.log(number)
print("The natural logarithm of", number, "is", natural_logarithm)
# Out:
# The natural logarithm of 2.718281828459045 is 1.0

# %%
#calculate e raised to the power of x using math.exp
import math
x = 1
e_power_x = math.exp(x)
print("e raised to the power of", x, "is", e_power_x)
# Out:
# e raised to the power of 1 is 2.718281828459045

# %%
#calculate the value of pi and eulers number from the math module
import math
pi = math.pi
e = math.e
print("The value of pi is", pi)
print("The value of e is", e)
# Out:
# The value of pi is 3.141592653589793
# The value of e is 2.718281828459045

# %%
#find the distance between two points using math.dist
import math
point1 = (1, 2)
point2 = (4, 6)
distance = math.dist(point1, point2)
print("The distance between", point1, "and", point2, "is", distance)
# Out:
# The distance between (1, 2) and (4, 6) is 5.0

# %%
#calculate the hypotenuse of a right angle triangle using math.hypot
import math
side1 = 3
side2 = 4
hypotenuse = math.hypot(side1, side2)
print("The hypotenuse of a right angle triangle with sides", side1, "and", side2, "is", hypotenuse)
# Out:
# The hypotenuse of a right angle triangle with sides 3 and 4 is 5.0

# %%
#find the combination using math.comb
import math
n = 5
k = 2
combination = math.comb(n, k)
print("The combination of", n, "and", k, "is", combination)
# Out:
# The combination of 5 and 2 is 10

# %%
#find the permutation using math.perm
import math
n = 5
k = 2
permutation = math.perm(n, k)
print("The permutation of", n, "and", k, "is", permutation)
# Out:
# The permutation of 5 and 2 is 20

# %%
#check whether a number is finite,infinite or nan using math.isinfinte,math.isinf,math.isnan
import math
number = 10
if math.isfinite(number):
    print(number, "is a finite number")
    if math.isinf(number):
        print(number, "is an infinite number")
    else:
        print(number, "is not an infinite number")
else:
    print(number, "is not a finite number")
# Out:
# 10 is a finite number
# 10 is not an infinite number

# %%
#find the product of all numbers using math.prod
import math
numbers = [1, 2, 3, 4, 5]
product = math.prod(numbers)
print("The product of all numbers is", product)
# Out:
# The product of all numbers is 120

# %%
#find the sum of square roots of all numbers in a list
import math
numbers = [1, 2, 3, 4, 5]
sum_of_square_roots = sum(math.sqrt(number) for number in numbers)
print("The sum of square roots of all numbers is"), sum_of_square_roots
# Out:
# The sum of square roots of all numbers is
# (None, 8.382332347441762)

# %%
#find the largest integer less than or equal to the square root of agiven number
import math
number = 16
largest_integer = math.floor(math.sqrt(number))
print("The largest integer less than or equal to the square root of", number, "is", largest_integer)
# Out:
# The largest integer less than or equal to the square root of 16 is 4

# %%
#calculate compound interest using math.pow
import math
principal = 1000
rate = 0.05
time = 5
compound_interest = principal * math.pow((1 + rate), time) - principal
print("The compound interest is", compound_interest)
# Out:
# The compound interest is 276.2815625000003

# %%
#find the area and circumference of a circle using math.pi
import math
radius = 5
area = math.pi * radius**2
circumference = 2 * math.pi * radius
print("The area of the circle is", area)
print("The circumference of the circle is", circumference)
# Out:
# The area of the circle is 78.53981633974483
# The circumference of the circle is 31.41592653589793

# %%
#create a scientific calculator that supports square root,factorial,logarithm,power,trignometric functions,GCD,and LCM
import math
print("=== scientific calculator ===")
print("1. square root")
print("2. factorial")
print("3. logarithm")
print("4. power")
print("5. trignometric functions")
print("6. GCD")
print("7. LCM")
choice = int(input("enter your choice: "))
if choice == 1:
    number = int(input("enter a number: "))
    print("the square root of", number, "is", math.sqrt(number))
elif choice == 2:
    number = int(input("enter a number: "))
    print("the factorial of", number, "is", math.factorial(number))
elif choice == 3:
    number = int(input("enter a number: "))
    print("the logarithm of", number, "is", math.log(number))
elif choice == 4:
    base = int(input("enter a base: "))
    exponent = int(input("enter an exponent: "))
    print(base, "raised to the power of", exponent, "is", math.pow(base, exponent))
elif choice == 5:
    print("1. sine")
    print("2. cosine")
    print("3. tangent")
    print("4. inverse sine")
    print("5. inverse cosine")
    print("6. inverse tangent")
    subchoice = int(input("enter your choice: "))
    if subchoice == 1:
        angle = int(input("enter an angle: "))
        print("the sine of", angle, "is", math.sin(math.radians(angle)))
elif choice == 6:
    number1 = int(input("enter the first number: "))
    number2 = int(input("enter the second number: "))
    print("the GCD of", number1, "and", number2, "is", math.gcd(number1, number2))
elif choice == 7:
    number1 = int(input("enter the first number: "))
    number2 = int(input("enter the second number: "))
    print("the LCM of", number1, "and", number2, "is", math.lcm(number1, number2))
else:
    print("invalid choice")
# Out:
# === scientific calculator ===
# 1. square root
# 2. factorial
# 3. logarithm
# 4. power
# 5. trignometric functions
# 6. GCD
# 7. LCM
# enter your choice: 55
# invalid choice

# %% [markdown]
# PYTHON OPERATORS

# %%
#write a program to perform addition,subtraction,multiplication,division,floor division,modulus and exponential on two numbers
num1 = int(input("enter the first number: "))
num2 = int(input("enter the second number: "))
print("the sum of", num1, "and", num2, "is", num1 + num2)
print("the difference between", num1, "and", num2, "is", num1 - num2)
print("the product of", num1, "and", num2, "is", num1 * num2)
print("the quotient of", num1, "and", num2, "is", num1 / num2)
print("the floor division of", num1, "and", num2, "is", num1 // num2)
print("the modulus of", num1, "and", num2, "is", num1 % num2)
print("the exponential of", num1, "and", num2, "is", num1 ** num2)
# Out:
# enter the first number: 15
# enter the second number: 25
# the sum of 15 and 25 is 40
# the difference between 15 and 25 is -10
# the product of 15 and 25 is 375
# the quotient of 15 and 25 is 0.6
# the floor division of 15 and 25 is 0
# the modulus of 15 and 25 is 15
# the exponential of 15 and 25 is 252511682940423488616943359375

# %%
#swap two numbers without using a third variable
a = int(input("enter the first number: "))
b = int(input("enter the second number: "))
a,b = b,a
print("the first number after swapping is", a)
print("the second number after swapping is", b)
# Out:
# enter the first number: 55
# enter the second number: 45
# the first number after swapping is 45
# the second number after swapping is 55

# %%
#find whether a number is even or odd using modulus operator
num = int(input("enter a number: "))
if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# enter a number: 15
# 15 is odd

# %%
#reverse a three digit number using arithmetic operators
num = int(input("enter a three digit number: "))
a = num % 10
b = (num // 10) % 10
c = num // 100
reverse = a * 100 + b * 10 + c
print("the reverse of", num, "is", reverse)
# Out:
# enter a three digit number: 543
# the reverse of 543 is 345

# %%
#find the last digit and first digit of a given number
num = int(input("enter a number: "))
last_digit = num % 10
while num >= 10:
    num = num // 10
first_digit = num
print("the last digit of", num, "is", last_digit)
print("the first digit of", num, "is", first_digit)
# Out:
# enter a number: 5678
# the last digit of 5 is 8
# the first digit of 5 is 5

# %%
#demonstrate all assignment operators(=,+=,-=,*=,/=,//=,%=,**=)on a variable
x = 10
print("initial value of x is", x)
x += 5
print("value of x after x += 5 is", x)
x -= 3
print("value of x after x -= 3 is", x)
x *= 2
print("value of x after x *= 2 is", x)
x /= 4
print("value of x after x /= 4 is", x)
x //= 2
print("value of x after x //= 2 is", x)
x %= 3
print("value of x after x %= 3 is", x)
x **= 2
print("value of x after x **= 2 is", x)
# Out:
# initial value of x is 10
# value of x after x += 5 is 15
# value of x after x -= 3 is 12
# value of x after x *= 2 is 24
# value of x after x /= 4 is 6.0
# value of x after x //= 2 is 3.0
# value of x after x %= 3 is 0.0
# value of x after x **= 2 is 0.0

# %%
#update a bank account balance using compound assignment operators
balance = 1000
balance += 500
print("the updated balance is", balance)
balance -= 200
print("the updated balance is", balance)
balance *= 1.05
print("the updated balance is", balance)
balance
# Out:
# the updated balance is 1500
# the updated balance is 1300
# the updated balance is 1365.0
# 1365.0

# %%
#calculate the total marks using += inside aloop
n = int(input("enter the number of subjects: "))
total_marks = 0
for i in range(n):
    marks = int(input("enter the marks of subject " + str(i + 1) + ": "))
    total_marks += marks
print("the total marks is", total_marks)
# Out:
# enter the number of subjects: 5
# enter the marks of subject 1: 25
# enter the marks of subject 2: 15
# enter the marks of subject 3: 30
# enter the marks of subject 4: 36
# enter the marks of subject 5: 40
# the total marks is 146

# %%
#compare two numbers and print the larger number
num1 = int(input("enter the first number: "))
num2 = int(input("enter the second number: "))
if num1 > num2:
    print(num1, "is larger than", num2)
else:
    print(num2, "is larger than", num1)
# Out:
# enter the first number: 67
# enter the second number: 56
# 67 is larger than 56

# %%
#check whether three numbers are equal
num1 = int(input("enter the first number: "))
num2 = int(input("enter the second number: "))
num3 = int(input("enter the third number: "))
if num1 == num2 == num3:
    print("all three numbers are equal")
else:
    print("all three numbers are not equal")
# Out:
# enter the first number: 55
# enter the second number: 55
# enter the third number: 55
# all three numbers are equal

# %%
#find the largest among three numbers using comparision operators
num1 = int(input("enter the first number: "))
num2 = int(input("enter the second number: "))
num3 = int(input("enter the third number: "))
if num1 > num2 and num1 > num3:
    print(num1, "is the largest number")
elif num2 > num1 and num2 > num3:
    print(num2, "is the largest number")
else:
    print(num3, "is the largest number")
# Out:
# enter the first number: 63
# enter the second number: 87
# enter the third number: 24
# 87 is the largest number

# %%
#check whether a student is eligible to vote based on age
age = int(input("enter the age of the student: "))
if age >= 18:
    print("the student is eligible to vote")
else:
    print("the student is not eligible to vote")
# Out:
# enter the age of the student: 25
# the student is eligible to vote

# %%
#check if a person is eligible for a loan (age>21,and salary>30000)
age = int(input("enter the age of the person: "))
salary = int(input("enter the salary of the person: "))
if age > 21 and salary > 30000:
    print("the person is eligible for a loan")
else:
    print("the person is not eligible for a loan")
# Out:
# enter the age of the person: 25
# enter the salary of the person: 100000
# the person is eligible for a loan

# %%
#check if a number lies between 10 and 100 using logical operators
num = int(input("enter a number: "))
if num > 10 and num < 100:
    print("the number lies between 10 and 100")
else:
    print("the number does not lie between 10 and 1")
# Out:
# enter a number: 55
# the number lies between 10 and 100

# %%
#validate username and password using logical operators
username = input("enter the username: ")
password = input("enter the password: ")
if username == "admin" and password == "password123":
    print("login successful")
else:
    print("invalid username or password")
# Out:
# enter the username: teju
# enter the password: 587
# invalid username or password

# %%
#determine whether a year is aleap year using logical conditions
year = int(input("enter a year: "))
if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# enter a year: 2001
# 2001 is not a leap year

# %%
#find the bitwise AND,OR,XOR of two numbers
num1 = int(input("enter the first number: "))
num2 = int(input("enter the second number: "))
print("the bitwise AND of", num1, "and", num2, "is", num1 & num2)
print("the bitwise OR of", num1, "and", num2, "is", num1 | num2)
print("the bitwise XOR of", num1, "and", num2, "is", num1 ^ num2)
# Out:
# enter the first number: 87
# enter the second number: 94
# the bitwise AND of 87 and 94 is 86
# the bitwise OR of 87 and 94 is 95
# the bitwise XOR of 87 and 94 is 9

# %%
#perform left shift and right shift operations
num = int(input("enter a number: "))
shift = int(input("enter the number of bits to shift: "))
print("the left shift of", num, "by", shift, "bits is", num << shift)
print("the right shift of", num, "by", shift, "bits is", num >> shift)
# Out:
# enter a number: 89
# enter the number of bits to shift: 5
# the left shift of 89 by 5 bits is 2848
# the right shift of 89 by 5 bits is 2

# %%
#check whether a numbere is even using bitwise operator
num = int(input("enter a number: "))
if num & 1 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# enter a number: 73
# 73 is odd

# %%
#swap two numbers using XOR operator
a = int(input("enter the first number: "))
b = int(input("enter the second number: "))
a = a ^ b
b = a ^ b
a = a ^ b
print("the first number after swapping is", a)
print("the second number after swapping is", b)
# Out:
# enter the first number: 68
# enter the second number: 24
# the first number after swapping is 24
# the second number after swapping is 68

# %%
# Count the number of set bits in a number

num = 29  # Binary: 11101
count = 0

while num > 0:
    count += num & 1   # Check if the last bit is 1
    num = num >> 1     # Right shift by 1 bit

print("Number of set bits:", count)
# Out:
# Number of set bits: 4

# %%
   #demonstrate the difference between is and ==
   #example 1
   a = [1, 2, 3]
   b = [1, 2, 3]
   print(a == b)  # Output: True
   print(a is b)  # Output: False

   #example 2
   a = "hello"
   b = "hello"
   print(a == b)  # Output: True
   print(a is b)  # Output: True
# Out:
# True
# False
# True
# True

# %%
#check whether two variables refer to same list object
a = [1, 2, 3]
b = a
print(a is b)  # Output: True
# Out:
# True

# %%
#show the behaviour of is not with integers and lists
a = 5
b = 5
print(a is b)  # Output: True

a = [1, 2, 3]
b = [1, 2, 3]
print(a is b)  # Output: False
# Out:
# True
# False

# %%
#check whether a character exists in a string
string = "hello world"
character = "o"
if character in string:
    print("character exists in string")
else:
    print("character does not exist in string")
# Out:
# character exists in string

# %%
#check whether a number exists in a list
numbers = [1, 2, 3, 4, 5]
number = 3
if number in numbers:
    print("number exists in list")
else:
    print("number does not exist in list")
# Out:
# number exists in list

# %%
#count how many vowels in a string belong to a predefined vowel list using in
vowels = ["a", "e", "i", "o", "u"]
string = "hello world"
count = 0
for char in string:
    if char in vowels:
        count += 1
print("number of vowels in string:", count)
# Out:
# number of vowels in string: 3

# %%
#build a simple calculator using arithmetic and comparision operators
#simple calculator
num1 = float(input("enter the first number: "))
op = input("enter the operator: ")
num2 = float(input("enter the second number: "))
if op == "+":
    print(num1 + num2)
elif op == "-":
    print(num1 - num2)
elif op == "*":
    print(num1 * num2)
elif op == "/":
    print(num1 / num2)
else:
    print("invalid operator")
# Out:
# enter the first number: 50
# enter the operator: 10
# enter the second number: 40
# invalid operator

# %%
marks = int(input("Enter your marks: "))

if marks >= 90 and marks <= 100:
    print("Grade: A+")

elif marks >= 80 and marks < 90:
    print("Grade: A")

elif marks >= 70 and marks < 80:
    print("Grade: B")

elif marks >= 60 and marks < 70:
    print("Grade: C")

elif marks >= 50 and marks < 60:
    print("Grade: D")

elif marks >= 0 and marks < 50:
    print("Grade: F")

else:
    print("Invalid marks")
# Out:
# Enter your marks: 50
# Grade: D
