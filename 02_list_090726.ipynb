# %%
#bank = [ [ ["C101","rahul","savings",85000],["C102","anitha","current",150000],["C103","kiran","loan",500000] ],
#[ ["C104","sneha","savings",95000],["C105","vikram","current",275000],["C106","meena","loan",750000] ] ]

# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
             ["C103", "Kiran", "Loan", 500000]
        ],
            [ ["C104", "Sneha", "Savings", 95000],
             ["C105", "Vikram", "Current", 275000],
              ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]



bank = [[ [ ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
             ["C103", "Kiran", "Loan", 500000]
        ],
            [ ["C104", "Sneha", "Savings", 95000],
             ["C105", "Vikram", "Current", 275000],
              ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]
print(bank[0])
# Out:
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
#rahuls complete record
print(bank[0][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
#print anithas account type
print(bank[0][0][1][2])
# Out:
# Current

# %%
#print kirans loan amount
print(bank[0][0][2][3])
# Out:
# 500000

# %%
#print snehas customer id
print(bank[0][1][0][0])
# Out:
# C104

# %%
#print vikrams balance
print(bank[0][1][1][3])
# Out:
# 275000

# %%
#print meenas complete record
print(bank[0][1][2])
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
#print arjuns customer id
print(bank[1][0][0][0])
# Out:
# C201

# %%
#print poojas name
print(bank[1][0][1][1])
# Out:
# Pooja

# %%
#print ramesh's account type
print(bank[1][0][2][2])
# Out:
# Loan

# %%
#print priyas balance
print(bank[1][1][0][3])
# Out:
# 45000

# %%
#print amits account type
print(bank[1][1][1][2])
# Out:
# Current

# %%
#print divyas customer id
print(bank[1][1][2][0])
# Out:
# C206

# %%
#print nikhils account type
print(bank[2][0][0][2])
# Out:
# Savings

# %%
#print kavyas balance
print(bank[2][0][1][3])
# Out:
# 240000

# %%
#print suresh's loan amount
print(bank[2][0][2][3])
# Out:
# 1000000

# %%
#print nehas name
print(bank[2][1][0][1])
# Out:
# Neha

# %%
#print rohans complete record
print(bank[2][1][1])
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
#print ashas account type
print(bank[2][1][2][2])
# Out:
# Loan

# %%
#print all customers in bank 1 branch 1
print(bank[0][0])
# Out:
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
#print all customers in bank 1 branch 2
print(bank[0][1])
# Out:
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
#print all customers in bank 2 branch 1
print(bank[1][0])
# Out:
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
#print all customers in bank 2 branch 2
print(bank[1][1])
# Out:
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
#print all customers in bank 3 branch 1
print(bank[2][0])
# Out:
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
#print al customers in bank 3 branch2
print(bank[2][1])
# Out:
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
#print all branches of bank1
print(bank[0])
# Out:
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
#print all branches of bank 2
print(bank[1])
# Out:
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
#print all branches of bank 3
print(bank[2])
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
#print the first customer from every banks first branch
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]

# %%
#print the second customer from every banks second branch
print(bank[0][0][1])
print(bank[1][0][1])
print(bank[2][0][1])
# Out:
# ['C102', 'Anita', 'Current', 150000]
# ['C202', 'Pooja', 'Current', 325000]
# ['C302', 'Kavya', 'Current', 240000]

# %%
#print the loan amount of the last customer in bank 3,branch 2
print(bank[2][1][2][3])
# Out:
# 550000

# %%
#create a list of 5 employee names and add anew employee using append()

p = ["ram","seetha","laxman","bablu","teju"]
p.append("apple")
print(p)
# Out:
# ['ram', 'seetha', 'laxman', 'bablu', 'teju', 'apple']

# %%
#create a list of account numbers and add three new account numbers using extend
q = [101,102,103,104,105]
q.extend([106,107,108])
print(q)
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %%
#insert a new customer at the begining of the customer list using insert
r = ["ram","seetha","laxman","bablu","teju"]
r.insert(0,"apple")
print(r)
# Out:
# ['apple', 'ram', 'seetha', 'laxman', 'bablu', 'teju']

# %%
#insert a transaction amount at index 3 in a list
s = [100,200,300,400,500]
s.insert(3,600)
print(s)
# Out:
# [100, 200, 300, 600, 400, 500]

# %%
#remove the last item from alist using pop
t = [100,200,300,400,500]
t.pop()
print(t)
# Out:
# [100, 200, 300, 400]

# %%
#remove the customer rahul from alist using remove
u = ["rahul","seetha","laxman","bablu","teju"]
u.remove("rahul")
print(u)
# Out:
# ['seetha', 'laxman', 'bablu', 'teju']

# %%
#count how many times the account type "savings" appear in a list using count
v = ["savings","current","savings","loan","savings"]
print(v.count("savings"))
# Out:
# 3

# %%
#find the index of current in a list of account types using index
w = ["savings","current","savings","loan","savings"]
print(w.index("current"))
# Out:
# 1

# %%
#reverse a list of transaction ID's using reverse
x = [101,102,103,104,105]
x.reverse()
print(x)
# Out:
# [105, 104, 103, 102, 101]

# %%
#sort a list of account balances in ascending order using sort
y = [500,300,245,100,10]
y.sort()
print(y)
# Out:
# [10, 100, 245, 300, 500]

# %%
#sort a list of cutomer names in descending order using sort
z = ["ram","seetha","laxman","bablu","teju"]
z.sort(reverse=True)
print(z)
# Out:
# ['teju', 'seetha', 'ram', 'laxman', 'bablu']

# %%
#make a copy of a list using copy and verify that modifying the copied list does not affect the original list
a = [100,200,300,400,500]
b = a.copy()
b.append(600)
print(a)
print(b)
# Out:
# [100, 200, 300, 400, 500]
# [100, 200, 300, 400, 500, 600]

# %%
#clear all elements from a list using clear
c = [100,200,300,400,500]
c.clear()
print(c)
# Out:
# []

# %%
#append a nested list containing a new customers details to an existing customer list
d = [["rahul","savings",85000],["anitha","current",150000],["kiran","loan",500000]]
d.append(["sneha","savings",95000])
print(d)
# Out:
# [['rahul', 'savings', 85000], ['anitha', 'current', 150000], ['kiran', 'loan', 500000], ['sneha', 'savings', 95000]]

# %%
#extend a list of branch names with another list of new branches
customers = ["priya","divya","ram","laxmi"]
new_customers = ["arjun","vikram"]
customers.extend(new_customers)
print(customers)
# Out:
# ['priya', 'divya', 'ram', 'laxmi', 'arjun', 'vikram']

# %%
#remove the first occurence of the balance 50000 from a list using remove
e = [10000,20000,30000,40000,50000,60000,50000,]
e.remove(50000)
print(e)
# Out:
# [10000, 20000, 30000, 40000, 60000, 50000]

# %%
#pop the element at index 2 from a list and print the removed value
f = [100,200,300,400,500]
f.pop(2)
print(f)
# Out:
# [100, 200, 400, 500]

# %%
#count how many times the city bangalore appears from a list
g = ["bangalore","delhi","bangalore","chennai","bangalore"]
print(g.count("bangalore"))
# Out:
# 3

# %%
#reverse the list of bank names and print the result
h = ["sbi","hdfc","icici","axis"]
h.reverse()
print(h)
# Out:
# ['axis', 'icici', 'hdfc', 'sbi']

# %%
#create a list of loan amounts and sort it in descending order
i = [1067,8769,2256,1896,5555]
i.sort(reverse=True)
print(i)
# Out:
# [8769, 5555, 2256, 1896, 1067]

# %%
#sample sets
bank_branches = {"mg road","indhira nagar","whitefield","electronic city"}
customers = {"rahul","anitha","kiran","sneha","vikram"}
new_customers = {"amit","rahul","priya","divya"}
loan_customers = {"rahul","kiran","asha","ramesh"}
savings_customers = {"rahul","sneha","priya","nikhil"}
transaction_ids = {101,102,103,104,105}
balances = {85000,120000,45000,95000,275000}
cities = {"bangalore","hyderabad","chennai","pune"}
new_cities = {"mumbai","bangalore","chennai"}
account_types = {"savings","current","loan"}


print(customers)
# Out:
# {'vikram', 'anitha', 'rahul', 'sneha', 'kiran'}

# %%
#find the number of elements in the custromer set
print(len(customers))
# Out:
# 5

# %%
#check whether rahul exists in the customer set
print("rahul" in customers)
# Out:
# True

# %%
#check whether meena exists in the customer list
print("meena" in customers)
# Out:
# False

# %%
#iterate through all elements in the bank_branches set
for branch in bank_branches:
    print(branch)
# Out:
# whitefield
# mg road
# electronic city
# indhira nagar

# %%
#add meena to the customers set
customers.add("meena")
print(customers)
# Out:
# {'vikram', 'anitha', 'rahul', 'sneha', 'meena', 'kiran'}

# %%
#add mysore to the city set
cities.add("mysore")
print(cities)
# Out:
# {'bangalore', 'pune', 'chennai', 'hyderabad', 'mysore'}

# %%
#update the customers set with new_customers
customers.update(new_customers)
print(customers)
# Out:
# {'anitha', 'amit', 'rahul', 'divya', 'priya', 'kiran', 'vikram', 'mysore', 'sneha', 'meena'}

# %%
#update the city set with new_cities
cities.update(new_cities)
print(cities)
# Out:
# {'mumbai', 'bangalore', 'pune', 'chennai', 'hyderabad', 'mysore'}

# %%
#remove rahul ffrom the customers set
customers.remove("rahul")
print(customers)
# Out:
# {'anitha', 'amit', 'divya', 'priya', 'kiran', 'vikram', 'mysore', 'sneha', 'meena'}

# %%
#remove pune from the city set
cities.remove("pune")
print(cities)
# Out:
# {'mumbai', 'bangalore', 'chennai', 'hyderabad', 'mysore'}

# %%
#discard anitha from the customers set
customers.discard("anitha")
print(customers)
# Out:
# {'amit', 'divya', 'priya', 'kiran', 'vikram', 'mysore', 'sneha', 'meena'}

# %%
#discard delhi from the city set
cities.discard("delhi")
print(cities)
# Out:
# {'mumbai', 'bangalore', 'chennai', 'hyderabad', 'mysore'}

# %%
#discard kolkata from the city set
cities.discard("kolkata")
print(cities)
# Out:
# {'mumbai', 'bangalore', 'chennai', 'hyderabad', 'mysore'}

# %%
#remove a random element from the trasaction id's using pop
transaction_ids.pop()
print(transaction_ids)
# Out:
# {102, 103, 104, 105}

# %%
#remove another random element from the account_types set
account_types.pop()
print(account_types)
# Out:
# {'loan', 'savings'}

# %%
#remove all elements from the balances set
balances.clear()
print(balances)
# Out:
# set()

# %%
#create a copy of the customers set
customers_copy = customers.copy()
print(customers_copy)
# Out:
# {'divya', 'priya', 'kiran', 'meena', 'vikram', 'mysore', 'amit', 'sneha'}

# %%
#modify the copied set and verify that the original set remains unchanges
customers_copy.add("apple")
print(customers_copy)
print(customers)
# Out:
# {'apple', 'divya', 'priya', 'kiran', 'meena', 'vikram', 'mysore', 'amit', 'sneha'}
# {'amit', 'divya', 'priya', 'kiran', 'vikram', 'mysore', 'sneha', 'meena'}

# %%
customers = {"rahul","anitha","kiran","sneha","vikram"}
new_customers = {"amit","rahul","priya","divya"}
#find common customers between customers and new customers
print(customers.intersection(new_customers))
# Out:
# {'rahul'}

# %%
#find customers who have both savings and loan acount
savings_customers = {"rahul","sneha","priya","nikhil"}
loan_customers = {"rahul","kiran","asha","ramesh"}
print(savings_customers.intersection(loan_customers))
# Out:
# {'rahul'}

# %%
customers = {"rahul","anitha","kiran","sneha","vikram"}
new_customers = {"amit","rahul","priya","divya"}
#find customers present only in customers but not in new_customers
print(customers.difference(new_customers))
# Out:
# {'kiran', 'vikram', 'anitha', 'sneha'}

# %%
customers = {"rahul","anitha","kiran","sneha","vikram"}
new_customers = {"amit","rahul","priya","divya"}
loan_customers = {"rahul","kiran","asha","ramesh"}
savings_customers = {"rahul","sneha","priya","nikhil"}
#find customers who have only savings account
(customers.intersection(savings_customers))
# Out:
# {'rahul', 'sneha'}

# %%
#sample sets
bank_branches = {"mg road","indhira nagar","whitefield","electronic city"}
customers = {"rahul","anitha","kiran","sneha","vikram"}
new_customers = {"amit","rahul","priya","divya"}
loan_customers = {"rahul","kiran","asha","ramesh"}
savings_customers = {"rahul","sneha","priya","nikhil"}
transaction_ids = {101,102,103,104,105}
balances = {85000,120000,45000,95000,275000}
cities = {"bangalore","hyderabad","chennai","pune"}
new_cities = {"mumbai","bangalore","chennai"}
account_types = {"savings","current","loan"}


#find customers that are present in either customers or new_customers but not both
print(customers.symmetric_difference(new_customers))
# Out:
# {'anitha', 'divya', 'priya', 'kiran', 'vikram', 'amit', 'sneha'}

# %%
#check whether{"rahul","kiran" is a subset of loan customers
print({"rahul","kiran"}.issubset(loan_customers))
# Out:
# True

# %%
#check whether customers is a supeerset of rahul,anitha
print(customers.issuperset({"rahul","anitha"}))
# Out:
# True

# %%
#check whether loan customers and new_cities are disjoint
print(loan_customers.isdisjoint(new_cities))
# Out:
# True

# %%
#find the maximum balances in the balance set
print(max(balances))
# Out:
# 275000

# %%
#find the minimum balances in the balance set
print(min(balances))
# Out:
# 45000

# %%
#find the total of all balances
print(sum(balances))
# Out:
# 620000

# %%
#sort the balances set in ascending order
print(sorted(balances))
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %%
#convert the customers set into a list
print(list(customers))
# Out:
# ['vikram', 'anitha', 'rahul', 'sneha', 'kiran']

# %%
#convert the cities set into atuple
print(tuple(cities))
# Out:
# ('chennai', 'pune', 'bangalore', 'hyderabad')

# %%
#remove duplicates from the list:
["rahul","rahul","anitha","sneha","sneha"]
print(set(["rahul","rahul","anitha","sneha","sneha"]))
# Out:
# {'rahul', 'anitha', 'sneha'}

# %%
#create an empty set
print(set())
# Out:
# set()

# %%
#add five employee names to the empty set
p = set()
p.add("ram")
p.add("seetha")
p.add("laxman")
p.add("bablu")
p.add("teju")
print(p)
# Out:
# {'laxman', 'teju', 'seetha', 'bablu', 'ram'}

# %%
#find the length of the account_types set
print(len(account_types))
# Out:
# 3

# %%
#print every element of the loan customers set using a loop
for customer in loan_customers:
    print(customer)
# Out:
# rahul
# asha
# ramesh
# kiran

# %%
#clear the transaction_ID's set and verify that it is empty
transaction_ids.clear()
print(transaction_ids)
# Out:
# set()
